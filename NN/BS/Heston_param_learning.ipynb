# %%
# 1. Imports and configuration
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt

print("PyTorch version:", torch.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Optional Black-Scholes utilities (uncomment if needed)
# import d10122f4_7b4a_4370_a214_edef01eb206b as bs_utils

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
plt.style.use("seaborn-v0_8")
# Out:
# PyTorch version: 2.5.1
# Using device: cuda

# %%
# 2. Load the CSV and basic checks
CSV_PATH = "../Heston_call.csv"  # adjust if needed

df = pd.read_csv(CSV_PATH)
print("Loaded shape:", df.shape)
display(df.head())

required_cols = ["S0", "K", "T", "C_mkt"]
for col in required_cols:
    if col not in df.columns:
        raise ValueError(f"Missing required column: {col}")

if "r" not in df.columns:
    df["r"] = 0.02
if "q" not in df.columns:
    df["q"] = 0.0

df = df.dropna(subset=["S0", "K", "T", "r", "q", "C_mkt"]).reset_index(drop=True)
df = df[df["T"] > 0.0].reset_index(drop=True)

print("Final number of rows:", len(df))
print(df[["S0", "K", "T", "r", "q", "C_mkt"]].describe())
# Out:
# Loaded shape: (2725, 6)
#            S0      K   C_mkt         T type       iv
# 0  667.840027  570.0   93.78  0.006484    C  0.00001
# 1  667.840027  575.0  102.28  0.006484    C  0.00001
# 2  667.840027  580.0   85.62  0.006484    C  0.00001
# 3  667.840027  590.0   75.65  0.006484    C  0.00001
# 4  667.840027  600.0   76.35  0.006484    C  0.00001
# Final number of rows: 2725
#                 S0            K            T             r       q  \
# count  2725.000000  2725.000000  2725.000000  2.725000e+03  2725.0
# mean    667.840027   658.623119     0.407258  2.000000e-02     0.0
# std       0.000000    69.045304     0.526842  3.470084e-18     0.0
# min     667.840027   518.000000     0.006484  2.000000e-02     0.0
# 25%     667.840027   609.000000     0.055799  2.000000e-02     0.0
# 50%     667.840027   662.000000     0.209224  2.000000e-02     0.0
# 75%     667.840027   703.000000     0.590045  2.000000e-02     0.0
# max     667.840027   815.000000     2.184566  2.000000e-02     0.0
#
#              C_mkt
# count  2725.000000
# mean     50.598261
# std      49.798740
# min       0.010000
# 25%       4.760000
# 50%      36.470000
# 75%      86.110000
# max     205.280000

# %%
# 3. Analytic Heston pricing utilities (characteristic function + call price)
INTEGRAL_U_MAX = 200.0
INTEGRAL_STEPS = 512

def heston_cf_torch(u, T, S0, r, q, kappa, theta, sigma, rho, v0):
    """Heston characteristic function φ(u) computed in PyTorch (broadcastable)."""
    dtype = torch.float64
    complex_dtype = torch.complex128

    u = u.to(complex_dtype)
    S0 = torch.clamp(S0.to(dtype), min=1e-8)
    T = torch.clamp(T.to(dtype), min=1e-8)
    r = r.to(dtype)
    q = q.to(dtype)
    kappa = torch.clamp(kappa.to(dtype), min=1e-6)
    theta = torch.clamp(theta.to(dtype), min=1e-6)
    sigma = torch.clamp(sigma.to(dtype), min=1e-6)
    rho = torch.clamp(rho.to(dtype), min=-0.999, max=0.999)
    v0 = torch.clamp(v0.to(dtype), min=1e-8)

    i = torch.complex(torch.tensor(0.0, dtype=dtype, device=u.device),
                      torch.tensor(1.0, dtype=dtype, device=u.device))
    x0 = torch.log(S0)
    a = kappa * theta
    b = kappa - rho * sigma * i * u
    d = torch.sqrt(b * b + (sigma ** 2) * (u * u + i * u))
    g = (b - d) / (b + d)

    exp_neg_dT = torch.exp(-d * T)
    one_minus_g_exp = 1.0 - g * exp_neg_dT
    one_minus_g = 1.0 - g

    C = (r - q) * i * u * T + (a / (sigma ** 2)) * ((b - d) * T - 2.0 * torch.log(one_minus_g_exp / one_minus_g))
    D = ((b - d) / (sigma ** 2)) * ((1.0 - exp_neg_dT) / one_minus_g_exp)
    return torch.exp(C + D * v0 + i * u * x0)

def heston_call_price_torch(S0, K, T, r, q, kappa, theta, sigma, rho, v0,
                            u_max=INTEGRAL_U_MAX, n_u=INTEGRAL_STEPS):
    """Semi-analytic Heston call price computed via numerical integration (RMSE loss driver)."""
    device = S0.device
    dtype = torch.float64
    complex_dtype = torch.complex128

    def _to_batch(x):
        return x.to(dtype).unsqueeze(0)

    S0_b = _to_batch(S0)
    K_b = _to_batch(K)
    T_b = _to_batch(T)
    r_b = _to_batch(r)
    q_b = _to_batch(q)
    kappa_b = _to_batch(kappa)
    theta_b = _to_batch(theta)
    sigma_b = _to_batch(sigma)
    rho_b = _to_batch(rho)
    v0_b = _to_batch(v0)

    u = torch.linspace(1e-6, u_max, n_u, device=device, dtype=dtype).unsqueeze(1)
    u_complex = u.to(complex_dtype)

    cf1 = heston_cf_torch(u_complex - 1j, T_b, S0_b, r_b, q_b, kappa_b, theta_b, sigma_b, rho_b, v0_b)
    numer1 = torch.exp(-1j * u_complex * torch.log(K_b)) * cf1
    integrand1 = (numer1 / (1j * u_complex)).real

    cf2 = heston_cf_torch(u_complex, T_b, S0_b, r_b, q_b, kappa_b, theta_b, sigma_b, rho_b, v0_b)
    numer2 = torch.exp(-1j * u_complex * torch.log(K_b)) * cf2
    integrand2 = (numer2 / (1j * u_complex)).real

    du = u[1] - u[0]
    P1 = 0.5 + (du / math.pi) * integrand1.sum(dim=0)
    P2 = 0.5 + (du / math.pi) * integrand2.sum(dim=0)

    discount_stock = torch.exp(-q_b * T_b)
    discount_strike = torch.exp(-r_b * T_b)
    call = S0_b * discount_stock * P1 - K_b * discount_strike * P2
    return call.squeeze(0).to(torch.float32)

# %%
# 4. Prepare inputs (features) and target prices
input_cols = ["T", "K", "S0", "r", "q"]
if "iv" in df.columns:
    input_cols.append("iv")

X_raw = df[input_cols].values.astype(np.float32)
y_price = df[["C_mkt"]].values.astype(np.float32)

X_mean = X_raw.mean(axis=0, keepdims=True)
X_std = X_raw.std(axis=0, keepdims=True) + 1e-8
X_norm = (X_raw - X_mean) / X_std

X_tensor = torch.from_numpy(X_norm)
y_price_tensor = torch.from_numpy(y_price)

print(f"Feature tensor shape: {X_tensor.shape}")
print(f"Price tensor shape: {y_price_tensor.shape}")
# Out:
# Feature tensor shape: torch.Size([2725, 6])
# Price tensor shape: torch.Size([2725, 1])

# %%
# 5. Dataset and DataLoaders
class HestonDataset(Dataset):
    def __init__(self, X, price):
        self.X = X
        self.price = price

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.price[idx]

full_dataset = HestonDataset(X_tensor, y_price_tensor)
dataset_size = len(full_dataset)
val_size = max(1, int(0.2 * dataset_size)) if dataset_size >= 5 else max(1, dataset_size // 2)
train_size = dataset_size - val_size
if train_size <= 0:
    train_size, val_size = dataset_size, 0

if val_size > 0:
    train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])
else:
    train_dataset, val_dataset = full_dataset, None

batch_size = min(64, max(1, train_size)) if train_size > 0 else 1
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False) if val_dataset else None

print(f"Train size: {train_size}, Val size: {val_size}")
print(f"Batch size: {batch_size}")
# Out:
# Train size: 2180, Val size: 545
# Batch size: 64

# %%
# 6. Neural network mapping inputs -> Heston parameters (kappa, theta, sigma, rho, v0)
class HestonParamNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 5),
        )

    def forward(self, x):
        raw_params = self.net(x)
        kappa_raw, theta_raw, sigma_raw, rho_raw, v0_raw = torch.unbind(raw_params, dim=-1)
        kappa = nn.functional.softplus(kappa_raw) + 1e-4
        theta = nn.functional.softplus(theta_raw) + 1e-4
        sigma = nn.functional.softplus(sigma_raw) + 1e-4
        rho = torch.tanh(rho_raw)
        v0 = nn.functional.softplus(v0_raw) + 1e-6
        return torch.stack([kappa, theta, sigma, rho, v0], dim=-1)

input_dim = X_tensor.shape[1]
model = HestonParamNet(input_dim=input_dim).to(device)
print(model)
# Out:
# HestonParamNet(
#   (net): Sequential(
#     (0): Linear(in_features=6, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=5, bias=True)
#   )
# )

# %%
# 7. Loss function (RMSE on prices) and optimizer
def rmse_loss(pred, target):
    mse = torch.mean((pred - target) ** 2)
    return torch.sqrt(mse + 1e-8)

optimizer = optim.Adam(model.parameters(), lr=1e-3)

X_mean_tensor = torch.from_numpy(X_mean).to(device)
X_std_tensor = torch.from_numpy(X_std).to(device)
column_index = {col: idx for idx, col in enumerate(input_cols)}
idx_T = column_index["T"]
idx_K = column_index["K"]
idx_S0 = column_index["S0"]
idx_r = column_index["r"]
idx_q = column_index["q"]

# %%
# 8. Training loop (analytic Heston pricing inside)
num_epochs = 1000
history = {"train": [], "val": []}

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []
    for X_batch, price_batch in train_loader:
        X_batch = X_batch.to(device)
        price_batch = price_batch.to(device).squeeze(-1)

        optimizer.zero_grad()
        params = model(X_batch)
        kappa, theta, sigma, rho, v0 = torch.unbind(params, dim=-1)

        X_batch_unnorm = X_batch * X_std_tensor + X_mean_tensor
        T_batch = X_batch_unnorm[:, idx_T]
        K_batch = X_batch_unnorm[:, idx_K]
        S0_batch = X_batch_unnorm[:, idx_S0]
        r_batch = X_batch_unnorm[:, idx_r]
        q_batch = X_batch_unnorm[:, idx_q]

        pred_price = heston_call_price_torch(
            S0_batch, K_batch, T_batch, r_batch, q_batch,
            kappa, theta, sigma, rho, v0
        )

        loss = rmse_loss(pred_price, price_batch)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    train_rmse = float(np.mean(train_losses)) if train_losses else float('nan')
    history["train"].append(train_rmse)

    model.eval()
    val_rmse = float('nan')
    if val_loader is not None:
        val_losses = []
        with torch.no_grad():
            for X_batch, price_batch in val_loader:
                X_batch = X_batch.to(device)
                price_batch = price_batch.to(device).squeeze(-1)

                params = model(X_batch)
                kappa, theta, sigma, rho, v0 = torch.unbind(params, dim=-1)

                X_batch_unnorm = X_batch * X_std_tensor + X_mean_tensor
                T_batch = X_batch_unnorm[:, idx_T]
                K_batch = X_batch_unnorm[:, idx_K]
                S0_batch = X_batch_unnorm[:, idx_S0]
                r_batch = X_batch_unnorm[:, idx_r]
                q_batch = X_batch_unnorm[:, idx_q]

                pred_price = heston_call_price_torch(
                    S0_batch, K_batch, T_batch, r_batch, q_batch,
                    kappa, theta, sigma, rho, v0
                )

                loss = rmse_loss(pred_price, price_batch)
                val_losses.append(loss.item())
        val_rmse = float(np.mean(val_losses)) if val_losses else float('nan')
    history["val"].append(val_rmse)

    if epoch % 5 == 0 or epoch == 1:
        print(f"Epoch {epoch:4d} | Train RMSE (C_Heston vs C_mkt): {train_rmse:.6f} | Val RMSE: {val_rmse:.6f}")
# Out:
# Epoch    1 | Train RMSE (C_Heston vs C_mkt): 70509.547545 | Val RMSE: 56275.167969
# Epoch    5 | Train RMSE (C_Heston vs C_mkt): 18543.738630 | Val RMSE: 20254.123589
# Epoch   10 | Train RMSE (C_Heston vs C_mkt): 11918.041309 | Val RMSE: 14523.875977
# Epoch   15 | Train RMSE (C_Heston vs C_mkt): 9403.926060 | Val RMSE: 11471.277724
# Epoch   20 | Train RMSE (C_Heston vs C_mkt): 10027.888149 | Val RMSE: 11043.816026
# Epoch   25 | Train RMSE (C_Heston vs C_mkt): 6240.623807 | Val RMSE: 7626.850939
# Epoch   30 | Train RMSE (C_Heston vs C_mkt): 5578.779164 | Val RMSE: 6656.103841
# Epoch   35 | Train RMSE (C_Heston vs C_mkt): 4872.521756 | Val RMSE: 6005.335097
# Epoch   40 | Train RMSE (C_Heston vs C_mkt): 4697.660393 | Val RMSE: 5705.691732
# Epoch   45 | Train RMSE (C_Heston vs C_mkt): 4443.510812 | Val RMSE: 5283.103380
# Epoch   50 | Train RMSE (C_Heston vs C_mkt): 4159.241985 | Val RMSE: 5551.345052
# Epoch   55 | Train RMSE (C_Heston vs C_mkt): 4047.675642 | Val RMSE: 4830.551975
# Epoch   60 | Train RMSE (C_Heston vs C_mkt): 3669.016591 | Val RMSE: 5043.551622
# Epoch   65 | Train RMSE (C_Heston vs C_mkt): 3882.123295 | Val RMSE: 4615.381619
# Epoch   70 | Train RMSE (C_Heston vs C_mkt): 3483.786914 | Val RMSE: 4382.377808
# Epoch   75 | Train RMSE (C_Heston vs C_mkt): 3590.209155 | Val RMSE: 4398.656413
# Epoch   80 | Train RMSE (C_Heston vs C_mkt): 3841.958094 | Val RMSE: 3986.677043
# Epoch   85 | Train RMSE (C_Heston vs C_mkt): 3130.347513 | Val RMSE: 3805.004639
# Epoch   90 | Train RMSE (C_Heston vs C_mkt): 3492.471143 | Val RMSE: 4486.253988
# Epoch   95 | Train RMSE (C_Heston vs C_mkt): 2944.082781 | Val RMSE: 3821.789008
# Epoch  100 | Train RMSE (C_Heston vs C_mkt): 2634.448263 | Val RMSE: 3378.789076
# Epoch  105 | Train RMSE (C_Heston vs C_mkt): 2663.290817 | Val RMSE: 3100.312839
# Epoch  110 | Train RMSE (C_Heston vs C_mkt): 2556.399254 | Val RMSE: 3447.400133
# Epoch  115 | Train RMSE (C_Heston vs C_mkt): 2270.054447 | Val RMSE: 3258.904256
# Epoch  120 | Train RMSE (C_Heston vs C_mkt): 2125.331637 | Val RMSE: 2950.796807
# Epoch  125 | Train RMSE (C_Heston vs C_mkt): 2093.268771 | Val RMSE: 2858.755154
# Epoch  130 | Train RMSE (C_Heston vs C_mkt): 1894.193197 | Val RMSE: 2839.052178
# Epoch  135 | Train RMSE (C_Heston vs C_mkt): 1887.733034 | Val RMSE: 2784.436768
# Epoch  140 | Train RMSE (C_Heston vs C_mkt): 1774.593220 | Val RMSE: 2900.038778
# Epoch  145 | Train RMSE (C_Heston vs C_mkt): 1833.338711 | Val RMSE: 2903.725776
# Epoch  150 | Train RMSE (C_Heston vs C_mkt): 1812.629796 | Val RMSE: 2303.886712
# Epoch  155 | Train RMSE (C_Heston vs C_mkt): 1729.737022 | Val RMSE: 2262.137431
# Epoch  160 | Train RMSE (C_Heston vs C_mkt): 1660.942069 | Val RMSE: 2188.278761
# Epoch  165 | Train RMSE (C_Heston vs C_mkt): 1568.993220 | Val RMSE: 2448.091933
# Epoch  170 | Train RMSE (C_Heston vs C_mkt): 2148.489715 | Val RMSE: 2251.181410
# Epoch  175 | Train RMSE (C_Heston vs C_mkt): 1568.933941 | Val RMSE: 2127.388597
# Epoch  180 | Train RMSE (C_Heston vs C_mkt): 1454.750093 | Val RMSE: 1943.635776
# Epoch  185 | Train RMSE (C_Heston vs C_mkt): 1470.731328 | Val RMSE: 2240.215563
# Epoch  190 | Train RMSE (C_Heston vs C_mkt): 1372.096132 | Val RMSE: 2380.857083
# Epoch  195 | Train RMSE (C_Heston vs C_mkt): 1632.532781 | Val RMSE: 1992.038079
# Epoch  200 | Train RMSE (C_Heston vs C_mkt): 1405.247433 | Val RMSE: 2008.813504
# Epoch  205 | Train RMSE (C_Heston vs C_mkt): 1339.358521 | Val RMSE: 2106.447700
# Epoch  210 | Train RMSE (C_Heston vs C_mkt): 1191.906409 | Val RMSE: 1829.705566
# Epoch  215 | Train RMSE (C_Heston vs C_mkt): 1344.487186 | Val RMSE: 1897.625156
# Epoch  220 | Train RMSE (C_Heston vs C_mkt): 1283.171475 | Val RMSE: 2187.328098
# Epoch  225 | Train RMSE (C_Heston vs C_mkt): 1211.734647 | Val RMSE: 1871.940538
# Epoch  230 | Train RMSE (C_Heston vs C_mkt): 1376.314106 | Val RMSE: 1808.019470
# Epoch  235 | Train RMSE (C_Heston vs C_mkt): 1271.559714 | Val RMSE: 1802.707174
# Epoch  240 | Train RMSE (C_Heston vs C_mkt): 1153.852598 | Val RMSE: 1712.243869
# Epoch  245 | Train RMSE (C_Heston vs C_mkt): 1304.721313 | Val RMSE: 1803.482456
# Epoch  250 | Train RMSE (C_Heston vs C_mkt): 1241.365730 | Val RMSE: 1970.544257
# Epoch  255 | Train RMSE (C_Heston vs C_mkt): 1236.101610 | Val RMSE: 1647.327311
# Epoch  260 | Train RMSE (C_Heston vs C_mkt): 1150.876327 | Val RMSE: 1871.831604
# Epoch  265 | Train RMSE (C_Heston vs C_mkt): 1502.502822 | Val RMSE: 1635.431298
# Epoch  270 | Train RMSE (C_Heston vs C_mkt): 1154.538818 | Val RMSE: 1653.724202
# Epoch  275 | Train RMSE (C_Heston vs C_mkt): 1015.511128 | Val RMSE: 1634.147224
# Epoch  280 | Train RMSE (C_Heston vs C_mkt): 1363.533782 | Val RMSE: 1969.723796
# Epoch  285 | Train RMSE (C_Heston vs C_mkt): 1067.942379 | Val RMSE: 1941.758362
# Epoch  290 | Train RMSE (C_Heston vs C_mkt): 1184.398704 | Val RMSE: 2341.390584
# Epoch  295 | Train RMSE (C_Heston vs C_mkt): 1034.100364 | Val RMSE: 1790.665337
# Epoch  300 | Train RMSE (C_Heston vs C_mkt): 1153.485096 | Val RMSE: 1792.473999
# Epoch  305 | Train RMSE (C_Heston vs C_mkt): 1036.525991 | Val RMSE: 1749.349901
# Epoch  310 | Train RMSE (C_Heston vs C_mkt): 1145.074337 | Val RMSE: 2051.802321
# Epoch  315 | Train RMSE (C_Heston vs C_mkt): 1107.819749 | Val RMSE: 1717.404412
# Epoch  320 | Train RMSE (C_Heston vs C_mkt): 1070.193004 | Val RMSE: 1701.793715
# Epoch  325 | Train RMSE (C_Heston vs C_mkt): 1017.622941 | Val RMSE: 1672.805678
# Epoch  330 | Train RMSE (C_Heston vs C_mkt): 1023.437763 | Val RMSE: 1569.127706
# Epoch  335 | Train RMSE (C_Heston vs C_mkt): 991.638004 | Val RMSE: 1696.341600
# Epoch  340 | Train RMSE (C_Heston vs C_mkt): 1073.797700 | Val RMSE: 1766.512288
# Epoch  345 | Train RMSE (C_Heston vs C_mkt): 1007.522893 | Val RMSE: 1610.374478
# Epoch  350 | Train RMSE (C_Heston vs C_mkt): 1071.691990 | Val RMSE: 1827.705750
# Epoch  355 | Train RMSE (C_Heston vs C_mkt): 957.951656 | Val RMSE: 1559.761949
# Epoch  360 | Train RMSE (C_Heston vs C_mkt): 933.054513 | Val RMSE: 1570.717034
# Epoch  365 | Train RMSE (C_Heston vs C_mkt): 1220.316015 | Val RMSE: 1677.552171
# Epoch  370 | Train RMSE (C_Heston vs C_mkt): 916.317296 | Val RMSE: 1547.074239
# Epoch  375 | Train RMSE (C_Heston vs C_mkt): 912.605110 | Val RMSE: 1526.441399
# Epoch  380 | Train RMSE (C_Heston vs C_mkt): 987.429896 | Val RMSE: 1811.601807
# Epoch  385 | Train RMSE (C_Heston vs C_mkt): 1186.352503 | Val RMSE: 1743.767653
# Epoch  390 | Train RMSE (C_Heston vs C_mkt): 906.669182 | Val RMSE: 1528.288493
# Epoch  395 | Train RMSE (C_Heston vs C_mkt): 1045.765005 | Val RMSE: 1576.773119
# Epoch  400 | Train RMSE (C_Heston vs C_mkt): 828.652234 | Val RMSE: 1848.461433
# Epoch  405 | Train RMSE (C_Heston vs C_mkt): 858.665341 | Val RMSE: 1522.757901
# Epoch  410 | Train RMSE (C_Heston vs C_mkt): 1157.571614 | Val RMSE: 1669.859795
# Epoch  415 | Train RMSE (C_Heston vs C_mkt): 821.256843 | Val RMSE: 1478.942478
# Epoch  420 | Train RMSE (C_Heston vs C_mkt): 939.040482 | Val RMSE: 1455.043260
# Epoch  425 | Train RMSE (C_Heston vs C_mkt): 789.392739 | Val RMSE: 1489.278324
# Epoch  430 | Train RMSE (C_Heston vs C_mkt): 830.335479 | Val RMSE: 1515.379578
# Epoch  435 | Train RMSE (C_Heston vs C_mkt): 938.307993 | Val RMSE: 1454.993469
# Epoch  440 | Train RMSE (C_Heston vs C_mkt): 954.001387 | Val RMSE: 1477.688653
# Epoch  445 | Train RMSE (C_Heston vs C_mkt): 1117.769988 | Val RMSE: 1624.600315
# Epoch  450 | Train RMSE (C_Heston vs C_mkt): 858.139178 | Val RMSE: 1486.726359
# Epoch  455 | Train RMSE (C_Heston vs C_mkt): 999.372091 | Val RMSE: 1868.405680
# Epoch  460 | Train RMSE (C_Heston vs C_mkt): 873.230386 | Val RMSE: 1527.164822
# Epoch  465 | Train RMSE (C_Heston vs C_mkt): 884.690932 | Val RMSE: 1373.405256
# Epoch  470 | Train RMSE (C_Heston vs C_mkt): 759.469525 | Val RMSE: 1410.852888
# Epoch  475 | Train RMSE (C_Heston vs C_mkt): 797.103571 | Val RMSE: 1400.036526
# Epoch  480 | Train RMSE (C_Heston vs C_mkt): 835.149030 | Val RMSE: 1403.949541
# Epoch  485 | Train RMSE (C_Heston vs C_mkt): 906.191375 | Val RMSE: 1425.350186
# Epoch  490 | Train RMSE (C_Heston vs C_mkt): 758.516000 | Val RMSE: 1452.376587
# Epoch  495 | Train RMSE (C_Heston vs C_mkt): 823.979187 | Val RMSE: 1377.528571
# Epoch  500 | Train RMSE (C_Heston vs C_mkt): 761.040211 | Val RMSE: 1395.432332
# Epoch  505 | Train RMSE (C_Heston vs C_mkt): 825.296679 | Val RMSE: 1309.277212
# Epoch  510 | Train RMSE (C_Heston vs C_mkt): 798.093518 | Val RMSE: 1530.961222
# Epoch  515 | Train RMSE (C_Heston vs C_mkt): 774.643001 | Val RMSE: 1339.838165
# Epoch  520 | Train RMSE (C_Heston vs C_mkt): 788.590541 | Val RMSE: 1748.473206
# Epoch  525 | Train RMSE (C_Heston vs C_mkt): 873.521414 | Val RMSE: 1326.387214
# Epoch  530 | Train RMSE (C_Heston vs C_mkt): 802.718154 | Val RMSE: 1447.752977
# Epoch  535 | Train RMSE (C_Heston vs C_mkt): 806.611976 | Val RMSE: 1345.246935
# Epoch  540 | Train RMSE (C_Heston vs C_mkt): 770.991019 | Val RMSE: 1369.172370
# Epoch  545 | Train RMSE (C_Heston vs C_mkt): 931.810899 | Val RMSE: 1719.649977
# Epoch  550 | Train RMSE (C_Heston vs C_mkt): 729.671637 | Val RMSE: 1409.411621
# Epoch  555 | Train RMSE (C_Heston vs C_mkt): 801.308258 | Val RMSE: 1430.727200
# Epoch  560 | Train RMSE (C_Heston vs C_mkt): 731.295652 | Val RMSE: 1300.980113
# Epoch  565 | Train RMSE (C_Heston vs C_mkt): 875.344564 | Val RMSE: 1366.078162
# Epoch  570 | Train RMSE (C_Heston vs C_mkt): 776.376041 | Val RMSE: 1315.728773
# Epoch  575 | Train RMSE (C_Heston vs C_mkt): 1160.009618 | Val RMSE: 1365.045417
# Epoch  580 | Train RMSE (C_Heston vs C_mkt): 815.153320 | Val RMSE: 1576.953227
# Epoch  585 | Train RMSE (C_Heston vs C_mkt): 731.644140 | Val RMSE: 1354.983449
# Epoch  590 | Train RMSE (C_Heston vs C_mkt): 706.775164 | Val RMSE: 1356.764852
# Epoch  595 | Train RMSE (C_Heston vs C_mkt): 751.190805 | Val RMSE: 1642.277622
# Epoch  600 | Train RMSE (C_Heston vs C_mkt): 723.473522 | Val RMSE: 1433.116102
# Epoch  605 | Train RMSE (C_Heston vs C_mkt): 679.117172 | Val RMSE: 1317.904494
# Epoch  610 | Train RMSE (C_Heston vs C_mkt): 845.601738 | Val RMSE: 1236.668223
# Epoch  615 | Train RMSE (C_Heston vs C_mkt): 858.995016 | Val RMSE: 1448.805596
# Epoch  620 | Train RMSE (C_Heston vs C_mkt): 754.216462 | Val RMSE: 1342.532739
# Epoch  625 | Train RMSE (C_Heston vs C_mkt): 850.829224 | Val RMSE: 1433.436211
# Epoch  630 | Train RMSE (C_Heston vs C_mkt): 770.340793 | Val RMSE: 1382.370144
# Epoch  635 | Train RMSE (C_Heston vs C_mkt): 703.605716 | Val RMSE: 1410.907630
# Epoch  640 | Train RMSE (C_Heston vs C_mkt): 640.536095 | Val RMSE: 1480.866374
# Epoch  645 | Train RMSE (C_Heston vs C_mkt): 692.258036 | Val RMSE: 1257.767358
# Epoch  650 | Train RMSE (C_Heston vs C_mkt): 802.504646 | Val RMSE: 1289.042447
# Epoch  655 | Train RMSE (C_Heston vs C_mkt): 951.410157 | Val RMSE: 1268.631968
# Epoch  660 | Train RMSE (C_Heston vs C_mkt): 827.245029 | Val RMSE: 1237.404751
# Epoch  665 | Train RMSE (C_Heston vs C_mkt): 745.489412 | Val RMSE: 1358.839600
# Epoch  670 | Train RMSE (C_Heston vs C_mkt): 679.758518 | Val RMSE: 1184.350918
# Epoch  675 | Train RMSE (C_Heston vs C_mkt): 694.541191 | Val RMSE: 1449.705214
# Epoch  680 | Train RMSE (C_Heston vs C_mkt): 808.309478 | Val RMSE: 1450.505866
# Epoch  685 | Train RMSE (C_Heston vs C_mkt): 613.657196 | Val RMSE: 1209.761522
# Epoch  690 | Train RMSE (C_Heston vs C_mkt): 984.014456 | Val RMSE: 1362.379462
# Epoch  695 | Train RMSE (C_Heston vs C_mkt): 682.741334 | Val RMSE: 1379.296122
# Epoch  700 | Train RMSE (C_Heston vs C_mkt): 724.111786 | Val RMSE: 1173.672197
# Epoch  705 | Train RMSE (C_Heston vs C_mkt): 709.655832 | Val RMSE: 1255.266320
# Epoch  710 | Train RMSE (C_Heston vs C_mkt): 683.718296 | Val RMSE: 1194.919830
# Epoch  715 | Train RMSE (C_Heston vs C_mkt): 644.973874 | Val RMSE: 1249.683204
# Epoch  720 | Train RMSE (C_Heston vs C_mkt): 684.871492 | Val RMSE: 1300.426344
# Epoch  725 | Train RMSE (C_Heston vs C_mkt): 861.328494 | Val RMSE: 1224.137431
# Epoch  730 | Train RMSE (C_Heston vs C_mkt): 637.633411 | Val RMSE: 1282.353448
# Epoch  735 | Train RMSE (C_Heston vs C_mkt): 642.681356 | Val RMSE: 1219.725911
# Epoch  740 | Train RMSE (C_Heston vs C_mkt): 772.192713 | Val RMSE: 1326.686707
# Epoch  745 | Train RMSE (C_Heston vs C_mkt): 633.558784 | Val RMSE: 1150.973090
# Epoch  750 | Train RMSE (C_Heston vs C_mkt): 691.724217 | Val RMSE: 1182.503282
# Epoch  755 | Train RMSE (C_Heston vs C_mkt): 657.413579 | Val RMSE: 1259.903720
# Epoch  760 | Train RMSE (C_Heston vs C_mkt): 657.245606 | Val RMSE: 1359.145637
# Epoch  765 | Train RMSE (C_Heston vs C_mkt): 564.486166 | Val RMSE: 1121.598112
# Epoch  770 | Train RMSE (C_Heston vs C_mkt): 670.480561 | Val RMSE: 1286.920180
# Epoch  775 | Train RMSE (C_Heston vs C_mkt): 600.177877 | Val RMSE: 1120.711409
# Epoch  780 | Train RMSE (C_Heston vs C_mkt): 677.171991 | Val RMSE: 1228.337216
# Epoch  785 | Train RMSE (C_Heston vs C_mkt): 539.753847 | Val RMSE: 1236.936818
# Epoch  790 | Train RMSE (C_Heston vs C_mkt): 616.844250 | Val RMSE: 1137.432312
# Epoch  795 | Train RMSE (C_Heston vs C_mkt): 718.207041 | Val RMSE: 1258.529809
# Epoch  800 | Train RMSE (C_Heston vs C_mkt): 650.839326 | Val RMSE: 1136.954529
# Epoch  805 | Train RMSE (C_Heston vs C_mkt): 602.333639 | Val RMSE: 1394.695760
# Epoch  810 | Train RMSE (C_Heston vs C_mkt): 614.103120 | Val RMSE: 1149.812771
# Epoch  815 | Train RMSE (C_Heston vs C_mkt): 610.615912 | Val RMSE: 1077.938867
# Epoch  820 | Train RMSE (C_Heston vs C_mkt): 774.402238 | Val RMSE: 1223.824690
# Epoch  825 | Train RMSE (C_Heston vs C_mkt): 671.245782 | Val RMSE: 1128.023651
# Epoch  830 | Train RMSE (C_Heston vs C_mkt): 600.395523 | Val RMSE: 1322.308865
# Epoch  835 | Train RMSE (C_Heston vs C_mkt): 602.483309 | Val RMSE: 1057.165100
# Epoch  840 | Train RMSE (C_Heston vs C_mkt): 610.249952 | Val RMSE: 1088.339830
# Epoch  845 | Train RMSE (C_Heston vs C_mkt): 504.953445 | Val RMSE: 1152.811293
# Epoch  850 | Train RMSE (C_Heston vs C_mkt): 585.240970 | Val RMSE: 1270.004537
# Epoch  855 | Train RMSE (C_Heston vs C_mkt): 579.528387 | Val RMSE: 1080.588535
# Epoch  860 | Train RMSE (C_Heston vs C_mkt): 583.052311 | Val RMSE: 1147.398560
# Epoch  865 | Train RMSE (C_Heston vs C_mkt): 614.572064 | Val RMSE: 1084.596564
# Epoch  870 | Train RMSE (C_Heston vs C_mkt): 916.454959 | Val RMSE: 1134.646054
# Epoch  875 | Train RMSE (C_Heston vs C_mkt): 570.297852 | Val RMSE: 1187.614329
# Epoch  880 | Train RMSE (C_Heston vs C_mkt): 615.921768 | Val RMSE: 1016.462762
# Epoch  885 | Train RMSE (C_Heston vs C_mkt): 563.578469 | Val RMSE: 1328.865448
# Epoch  890 | Train RMSE (C_Heston vs C_mkt): 792.266425 | Val RMSE: 1049.158773
# Epoch  895 | Train RMSE (C_Heston vs C_mkt): 566.535161 | Val RMSE: 1099.718333
# Epoch  900 | Train RMSE (C_Heston vs C_mkt): 531.647760 | Val RMSE: 1110.762936
# Epoch  905 | Train RMSE (C_Heston vs C_mkt): 493.521410 | Val RMSE: 1189.813300
# Epoch  910 | Train RMSE (C_Heston vs C_mkt): 709.655697 | Val RMSE: 1106.550018
# Epoch  915 | Train RMSE (C_Heston vs C_mkt): 549.307773 | Val RMSE: 1045.938158
# Epoch  920 | Train RMSE (C_Heston vs C_mkt): 646.511911 | Val RMSE: 1050.908203
# Epoch  925 | Train RMSE (C_Heston vs C_mkt): 556.597998 | Val RMSE: 1003.639282
# Epoch  930 | Train RMSE (C_Heston vs C_mkt): 558.696662 | Val RMSE: 1111.764659
# Epoch  935 | Train RMSE (C_Heston vs C_mkt): 557.322412 | Val RMSE: 1069.441562
# Epoch  940 | Train RMSE (C_Heston vs C_mkt): 575.409723 | Val RMSE: 1399.070713
# Epoch  945 | Train RMSE (C_Heston vs C_mkt): 663.594694 | Val RMSE: 1101.781959
# Epoch  950 | Train RMSE (C_Heston vs C_mkt): 769.146863 | Val RMSE: 1077.659844
# Epoch  955 | Train RMSE (C_Heston vs C_mkt): 527.373042 | Val RMSE: 926.104326
# Epoch  960 | Train RMSE (C_Heston vs C_mkt): 530.395023 | Val RMSE: 933.134976
# Epoch  965 | Train RMSE (C_Heston vs C_mkt): 750.836816 | Val RMSE: 1227.805956
# Epoch  970 | Train RMSE (C_Heston vs C_mkt): 444.786446 | Val RMSE: 878.267380
# Epoch  975 | Train RMSE (C_Heston vs C_mkt): 599.032881 | Val RMSE: 1019.828671
# Epoch  980 | Train RMSE (C_Heston vs C_mkt): 514.590095 | Val RMSE: 870.180661
# Epoch  985 | Train RMSE (C_Heston vs C_mkt): 620.748342 | Val RMSE: 1077.797953
# Epoch  990 | Train RMSE (C_Heston vs C_mkt): 516.667268 | Val RMSE: 954.769833
# Epoch  995 | Train RMSE (C_Heston vs C_mkt): 472.187370 | Val RMSE: 922.865987
# Epoch 1000 | Train RMSE (C_Heston vs C_mkt): 598.116542 | Val RMSE: 1109.452708

# %%
# 9. Evaluation and inspection of learned parameters
model.eval()
with torch.no_grad():
    X_full = X_tensor.to(device)
    price_full = y_price_tensor.squeeze(-1).to(device)
    params_full = model(X_full)
    kappa_full, theta_full, sigma_full, rho_full, v0_full = torch.unbind(params_full, dim=-1)

    X_full_unnorm = X_full * X_std_tensor + X_mean_tensor
    T_full = X_full_unnorm[:, idx_T]
    K_full = X_full_unnorm[:, idx_K]
    S0_full = X_full_unnorm[:, idx_S0]
    r_full = X_full_unnorm[:, idx_r]
    q_full = X_full_unnorm[:, idx_q]

    price_pred_full = heston_call_price_torch(
        S0_full, K_full, T_full, r_full, q_full,
        kappa_full, theta_full, sigma_full, rho_full, v0_full
    )

    final_rmse = math.sqrt(torch.mean((price_pred_full - price_full) ** 2).item())

print(f"Final RMSE on full dataset (C_Heston vs C_mkt): {final_rmse:.6f}")

params_np = {
    'kappa': kappa_full.cpu().numpy(),
    'theta': theta_full.cpu().numpy(),
    'sigma': sigma_full.cpu().numpy(),
    'rho': rho_full.cpu().numpy(),
    'v0': v0_full.cpu().numpy(),
}
for name, values in params_np.items():
    print(f"{name:>5}: mean={values.mean():.6f}, std={values.std():.6f}, min={values.min():.6f}, max={values.max():.6f}")

comparison = df.copy()
comparison["price_heston_nn"] = price_pred_full.cpu().numpy()
comparison["abs_error"] = np.abs(comparison["price_heston_nn"] - comparison["C_mkt"])
comparison["rel_error"] = comparison["abs_error"] / np.maximum(comparison["C_mkt"], 1e-8)

display_cols = ["S0", "K", "T", "C_mkt", "price_heston_nn", "abs_error", "rel_error"]
display(comparison[display_cols].head())

sample = comparison.sample(min(5, len(comparison)), random_state=SEED)
display(sample[display_cols])
# Out:
# Final RMSE on full dataset (C_Heston vs C_mkt): 1025.060181
# kappa: mean=66.349487, std=59.386948, min=0.653494, max=248.257767
# theta: mean=1.652600, std=3.379706, min=0.000101, max=17.967478
# sigma: mean=48.314754, std=42.134430, min=1.315583, max=152.131012
#   rho: mean=0.999979, std=0.000054, min=0.999699, max=1.000000
#    v0: mean=34.225864, std=32.846226, min=0.476586, max=167.515839
#            S0      K         T   C_mkt  price_heston_nn     abs_error  \
# 0  667.840027  570.0  0.006484   93.78     24893.527344  24799.747344
# 1  667.840027  575.0  0.006484  102.28     22456.355469  22354.075469
# 2  667.840027  580.0  0.006484   85.62     20446.423828  20360.803828
# 3  667.840027  590.0  0.006484   75.65     16923.255859  16847.605859
# 4  667.840027  600.0  0.006484   76.35     13198.653320  13122.303320
#
#     rel_error
# 0  264.446016
# 1  218.557640
# 2  237.804296
# 3  222.704638
# 4  171.870377
#               S0      K         T   C_mkt  price_heston_nn   abs_error  \
# 2228  667.840027  675.0  0.842100   48.88       268.829071  219.949071
# 1344  667.840027  560.0  0.209224  112.96      1068.023071  955.063071
# 1418  667.840027  648.0  0.209224   35.29       277.320160  242.030160
# 1833  667.840027  576.0  0.373607  111.20       537.191040  425.991040
# 605   667.840027  681.0  0.036621    3.36      -389.206329  392.566329
#
#        rel_error
# 2228    4.499776
# 1344    8.454878
# 1418    6.858321
# 1833    3.830855
# 605   116.835217
